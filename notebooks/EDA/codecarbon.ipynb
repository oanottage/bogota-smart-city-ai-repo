# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()  # Loads from .env by default

## Define base path (adjust if notebook is in different location)
BASE_PATH = os.getenv('BASE_PATH')

# Verify base path exists
if not BASE_PATH or not os.path.exists(BASE_PATH):
    raise ValueError(f"Invalid BASE_PATH: {BASE_PATH}. Check your .env file and directory structure")

# %%
emissions_df = pd.read_csv(os.path.join(BASE_PATH,"reports/codecarbon/emissions.csv"))

# %%
emissions_df.head()
# Out:
#              timestamp project_name                                run_id  \
# 0  2025-02-09T17:41:40   codecarbon  b0134a3f-3ac3-4022-af68-d02c31218cf5
# 1  2025-02-09T17:41:57   codecarbon  c04258a5-2354-47a2-8e1f-dfcbe7f4894b
# 2  2025-02-09T17:42:11   codecarbon  c7f3328c-ade3-4a02-8d33-829909b14427
#
#                           experiment_id  duration     emissions  \
# 0  5b0fa12a-3dd7-45bb-9766-cc326314d9f1  6.995588  4.615354e-07
# 1  5b0fa12a-3dd7-45bb-9766-cc326314d9f1  6.730162  4.446933e-07
# 2  5b0fa12a-3dd7-45bb-9766-cc326314d9f1  6.695525  2.832732e-07
#
#    emissions_rate  cpu_power  gpu_power  ram_power  ...  cpu_count  \
# 0    6.597521e-08     0.8639     0.0000       6.75  ...         11
# 1    6.607468e-08     0.6657     0.5467       6.75  ...         11
# 2    4.230784e-08     0.5092     0.0000       6.75  ...         11
#
#       cpu_model  gpu_count     gpu_model longitude latitude ram_total_size  \
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(emissions_df['timestamp'], emissions_df['emissions'])
plt.xlabel('Run')
plt.ylabel('Emissions (kg CO2)')
plt.title('CO2 Emissions by MLflow Run')
plt.show()
